# %% [markdown]
# <h1><p><center style="background: linear-gradient(to right,white,green);color: transparent;font-family: Gabriola;color: navy;font-size: 210%;text-align: center;border-radius: 10px 70px">
#      Deep Learning Predictive Modeling of Banking Churn
# </center></p></h1>

# %% [markdown]
# <div style="border-radius: 5px; font-family: cursive; border: 3px solid #007A33; background: #F6FFF9; color: black; font-size: 14px; padding: 15px;">
#   <p style="color: darkgreen; font-weight: bold; font-size: 16px;"> Data Project Aim & Solution (ANN Classification)</p>
#
#   <p style="color: #333; font-weight: bold;">🔹 Aim</p>
#   <ul style="margin-left:15px; line-height:1.6;">
#     <li>To develop an ANN-based classification pipeline to predict high-risk churn customers in the Banking .</li>
#     <li>To leverage deep learning for extracting patterns from customer behavior data and providing actionable insights for retention strategies.</li>
#     <li>To improve long-term customer loyalty and minimize revenue loss through proactive, data-driven predictions.</li>
#   </ul>
#
#   <p style="color: #333; font-weight: bold;">🔹 Data Preprocessing & Cleaning</p>
#   <ul style="margin-left:15px; line-height:1.6;">
#     <li>✅ Checked and imputed <b>missing values</b> (median for numeric, most frequent for categorical)</li>
#     <li> Removed <b>duplicates</b> and standardized column names & units</li>
#     <li> Detected & handled <b>outliers</b> using IQR methods</li>
#     <li> Computed derived features & replaced placeholders with numeric values</li>
#     <li> Built <b>correlation heatmap</b> to detect multicollinearity</li>
#   </ul>
#
#   <p style="color: #333; font-weight: bold;">🔹 ANN Preprocessing</p>
#   <ul style="margin-left:15px; line-height:1.6;">
#     <li> <b>Scaling:</b>  MinMaxScaler applied to numerical features</li>
#     <li> <b>Encoding:</b> OneHotEncoder for categorical features</li>
#     <li> <b>Train/Validation/Test Split:</b> e.g., 90/10 to avoid overfitting</li>
#     <li> <b>Feature Selection:</b> Dropped highly correlated or low-variance features</li>
#   </ul>
#
#   <p style="color: #333; font-weight: bold;">🔹 ANN Architecture & Regularization</p>
#   <ul style="margin-left:15px; line-height:1.6;">
#     <li><b> Two architecture:</b> 2 and 3 hidden layers (Dense) with Sigmoid activation</li>
#     <li> <b>Hyperparameter Optimization:</b> Optuna</li>
#     <li> <b>Learning Rate Scheduler:</b> ReduceLROnPlateau for adaptive training</li>
#     <li> <b>EarlyStopping:</b> patience=15 to stop training upon convergence</li>
#   </ul>
#
#   <p style="color: #333; font-weight: bold;">🔹 Model Evaluation</p>
#   <ul style="margin-left:15px; line-height:1.6;">
#     <li> Accuracy, Precision, Recall, F1-score (weighted)</li>
#     <li> OC-AUC and ROC curve comparison</li>
#     <li> Visualization of metrics for train/validation/test sets</li>
#   </ul>
#
#   <p style="color: #333; font-weight: bold;">🔹 Expected Impact</p>
#   <ul style="margin-left:15px; line-height:1.6;">
#     <li>Early detection of high-risk churn </li>
#     <li>Reduction of revenue loss through targeted retention campaigns</li>
#     <li>Enhanced customer satisfaction and long-term loyalty</li>
#   </ul>
# </div>

# %% [markdown]
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %% [markdown]
# <div style="border-radius: 5px; font-family: cursive; border: 3px solid #007A33; background: #F6FFF9; color: black; font-size: 14px; padding: 15px;">
#
# <p style="color: darkgreen; font-weight: bold; font-size: 16px;">
# 📊 Dataset Explanation
# </p>
#
# <p style="color:#333; font-weight:bold;">🔹 Dataset Overview</p>
#
# <p style="line-height:1.7;">
# This dataset contains information about a bank's customers and is designed for customer churn prediction.
# The objective is to determine whether a customer will leave the bank (Exited = 1) or remain with the bank (Exited = 0) based on demographic, financial, and account-related characteristics.
# </p>
#
# <p style="color:#333; font-weight:bold;">🔹 Dataset Features</p>
#
# <ul style="margin-left:15px; line-height:1.7;">
#
# <li><b>RowNumber</b> – Unique row index (1–10,000).</li>
#
# <li><b>CustomerId</b> – Unique identifier assigned to each customer.</li>
#
# <li><b>Surname</b> – Customer's last name.</li>
#
# <li><b>CreditScore</b> – Numerical credit score representing customer creditworthiness.</li>
#
# <li><b>Geography</b> – Customer's country or region (France, Germany, Spain).</li>
#
# <li><b>Gender</b> – Customer gender (Male/Female).</li>
#
# <li><b>Age</b> – Customer age in years.</li>
#
# <li><b>Tenure</b> – Number of years the customer has been with the bank.</li>
#
# <li><b>Balance</b> – Customer account balance.</li>
#
# <li><b>NumOfProducts</b> – Total number of banking products used by the customer.</li>
#
# <li><b>HasCrCard</b> – Indicates whether the customer owns a credit card (1 = Yes, 0 = No).</li>
#
# <li><b>IsActiveMember</b> – Indicates whether the customer is an active bank member (1 = Active, 0 = Inactive).</li>
#
# <li><b>Exited</b> – Target variable indicating customer churn (1 = Customer left the bank, 0 = Customer retained).</li>
#
# </ul>
#
# <p style="color:#333; font-weight:bold;">🔹 Target Variable</p>
#
# <ul style="margin-left:15px; line-height:1.7;">
# <li><b>Exited = 1</b> → Customer closed their bank account (Churn).</li>
# <li><b>Exited = 0</b> → Customer remained with the bank (Retained).</li>
# </ul>
#
# </div>

# %% [markdown]
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %% [markdown]
# <h1><p><center style="background: linear-gradient(to right,white,green);color: transparent;font-family: Gabriola;color: navy;font-size: 80%;text-align: center;border-radius: 10px 70px">
#      Libraries
# </center></p></h1>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.rcParams["figure.figsize"] = (10, 6)

sns.set_style("whitegrid")
pd.set_option("display.float_format", lambda x: "%.3f" % x)



# !pip install termcolor
import colorama
from colorama import Fore, Style  # makes strings colored
from termcolor import colored
from termcolor import cprint

from tensorflow import keras
import tensorflow as tf
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.layers import Dropout
from tensorflow.keras.callbacks import EarlyStopping

from sklearn.model_selection import cross_val_score, cross_validate 
from sklearn.metrics import RocCurveDisplay,accuracy_score, f1_score, recall_score,\
                            precision_score, make_scorer,\
                            classification_report,confusion_matrix,\
                            ConfusionMatrixDisplay, average_precision_score,\
                            roc_curve, roc_auc_score, auc
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, MultiLabelBinarizer
from sklearn.utils.class_weight import compute_class_weight
from scikitplot.metrics import plot_roc, precision_recall_curve,average_precision_score


# Uncomment the following lines if you want to suppress warnings:
import warnings
warnings.filterwarnings("ignore")
warnings.warn("this will not show")

# Set it to None to display all rows in the dataframe:
# pd.set_option('display.max_rows', None)

# Set it to None to display all columns in the dataframe:
pd.set_option("display.max_columns", None)

# %% [markdown]
# ## LINK OF DATA : https://www.kaggle.com/datasets/avhikj/churn-predictions-personal

# %% [markdown]
# <h1><p><center style="background: linear-gradient(to right,white,green);color: transparent;font-family: Gabriola;color: navy;font-size: 80%;text-align: center;border-radius: 10px 70px">
#       Data Loading
# </center></p></h1>

# %%
df0 = pd.read_csv('Churn_Predictions.csv')
df = df0.copy()
df.head()
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
df.shape
# Out:
# (10000, 14)

# %%
df.shape
# Out:
# (10000, 14)

# %%
df.drop(columns = ["RowNumber", "CustomerId", "Surname"], inplace = True)

# %%
df.describe().T
# Out:
#                     count       mean       std     min       25%        50%  \
# CreditScore     10000.000    650.529    96.653 350.000   584.000    652.000
# Age             10000.000     38.922    10.488  18.000    32.000     37.000
# Tenure          10000.000      5.013     2.892   0.000     3.000      5.000
# Balance         10000.000  76485.889 62397.405   0.000     0.000  97198.540
# NumOfProducts   10000.000      1.530     0.582   1.000     1.000      1.000
# HasCrCard       10000.000      0.706     0.456   0.000     0.000      1.000
# IsActiveMember  10000.000      0.515     0.500   0.000     0.000      1.000
# EstimatedSalary 10000.000 100090.240 57510.493  11.580 51002.110 100193.915
# Exited          10000.000      0.204     0.403   0.000     0.000      0.000
#
#                        75%        max
# CreditScore        718.000    850.000
# Age                 44.000     92.000
# Tenure               7.000     10.000
# Balance         127644.240 250898.090
# ...

# %% [markdown]
# <div style="border-radius: 5px; font-family: cursive; border: 3px solid #007A33; background: #F6FFF9; color: black; font-size: 14px; padding: 15px;">
#
# <p style="color: darkgreen; font-weight: bold; font-size: 16px;">
# 📏 Feature Scaling
# </p>
#
# <p style="line-height:1.7;">
# Inspection of the dataset shows that the numerical features have different value ranges, as indicated by their varying minimum and maximum values. Since Artificial Neural Networks (ANNs) are trained using gradient-based optimization algorithms, feature scaling is essential to ensure efficient learning and stable convergence.
# </p>
#
# <p style="line-height:1.7;">
# For this reason, feature scaling will be applied during the Deep Learning preprocessing stage. Standardization will transform the numerical variables to a common scale, improving model training speed, optimization performance, and prediction accuracy.
# </p>
#
# </div>

# %%
for i in df.columns[:]:
    print("*" * 30)
    print("Column Name: ", i)
    print()
    print("Number of NaN values in the column: ", df[i].isnull().sum())
    print()
    print("What percentage of the column consists of NaN values?", (df[i].isnull().sum() / len(df)) * 100)
    print()
    print("Value counts for the column:\n", df[i].value_counts(dropna=False))
# Out:
# ******************************
# Column Name:  CreditScore
#
# Number of NaN values in the column:  0
#
# What percentage of the column consists of NaN values? 0.0
#
# Value counts for the column:
#  CreditScore
# 850    233
# 678     63
# 655     54
# 705     53
# 667     53
#       ...
# 404      1
# 351      1
# 365      1
# 417      1
# 419      1
# Name: count, Length: 460, dtype: int64
# ******************************
# Column Name:  Geography
#
# Number of NaN values in the column:  0
#
# What percentage of the column consists of NaN values? 0.0
#
# Value counts for the column:
#  Geography
# France     5014
# Germany    2509
# Spain      2477
# Name: count, dtype: int64
# ******************************
# Column Name:  Gender
#
# Number of NaN values in the column:  0
#
# What percentage of the column consists of NaN values? 0.0
#
# Value counts for the column:
#  Gender
# Male      5457
# Female    4543
# Name: count, dtype: int64
# ******************************
# ...

# %%
sns.pairplot(df, hue = "Exited")

# %% [markdown]
# <div style="border-radius: 5px; font-family: cursive; border: 3px solid #007A33; background: #F6FFF9; color: black; font-size: 14px; padding: 15px;">
#
# <p style="color: darkgreen; font-weight: bold; font-size: 16px;">
# 📊 Feature Distribution Analysis
# </p>
#
# <p style="line-height:1.7;">
# The feature distributions indicate limited separation between customers who exited and those who remained with the bank. Several variables exhibit considerable overlap between the two classes, suggesting that individual features have relatively low discriminative power when considered independently.
# </p>
#
# <p style="line-height:1.7;">
# This observation highlights the importance of using machine learning and deep learning models capable of capturing complex, non-linear relationships and interactions among multiple features to improve customer churn prediction.
# </p>
#
# </div>

# %%
df["Geography"].value_counts(normalize = True) * 100
# Out:
# Geography
# France    50.140
# Germany   25.090
# Spain     24.770
# Name: proportion, dtype: float64

# %%
df["Exited"].value_counts(normalize = True) * 100
# Out:
# Exited
# 0   79.630
# 1   20.370
# Name: proportion, dtype: float64

# %%
(df["Geography"].value_counts(normalize = True)*100).plot(kind="barh", figsize=(7,7))
# Out:
# <Axes: ylabel='Geography'>

# %% [markdown]
# <div style="border-radius: 5px; font-family: cursive; border: 3px solid #007A33; background: #F6FFF9; color: black; font-size: 14px; padding: 15px;">
#
# <p style="color: darkgreen; font-weight: bold; font-size: 16px;">
# 🌍 Geography Distribution
# </p>
#
# <p style="line-height:1.7;">
# The distribution of customers across geographical regions is not balanced. France represents approximately <b>50%</b> of all customers in the dataset, while Germany and Spain each account for roughly <b>25%</b> of the observations.
# </p>
#
# <p style="line-height:1.7;">
# This indicates that the dataset is moderately imbalanced with respect to the <b>Geography</b> feature. Such a distribution should be considered during exploratory analysis, as geographic differences may influence customer behavior and churn patterns.
# </p>
#
# </div>

# %%
df.groupby(["Geography"])["Balance"].mean().plot(kind = "barh", figsize = (7,7))
# Out:
# <Axes: ylabel='Geography'>

# %% [markdown]
# <div style="border-radius: 5px; font-family: cursive; border: 3px solid #007A33; background: #F6FFF9; color: black; font-size: 14px; padding: 15px;">
#
# <p style="color: darkgreen; font-weight: bold; font-size: 16px;">
# 💰 Average Account Balance by Geography
# </p>
#
# <p style="line-height:1.7;">
# Analysis of the average account balance across different countries shows noticeable geographical differences. Customers from <b>Germany</b> have the highest average account balance, while customers from <b>France</b> and <b>Spain</b> exhibit relatively similar average balances.
# </p>
#
# <p style="line-height:1.7;">
# These findings suggest that customer financial profiles vary by region, making <b>Geography</b> a potentially important feature for understanding customer behavior and improving churn prediction models.
# </p>
#
# </div>

# %%
ax = sns.countplot(x=df["NumOfProducts"])
ax.bar_label(ax.containers[0]);

# %% [markdown]
# <div style="border-radius: 5px; font-family: cursive; border: 3px solid #007A33; background: #F6FFF9; color: black; font-size: 14px; padding: 15px;">
#
# <p style="color: darkgreen; font-weight: bold; font-size: 16px;">
# 🏦 Bank Product Usage
# </p>
#
# <p style="line-height:1.7;">
# The distribution of bank product usage shows that most customers use <b>one banking product</b>, making it the most common category in the dataset. In contrast, customers using <b>four products</b> represent the smallest proportion of the customer base.
# </p>
#
# <p style="line-height:1.7;">
# This distribution indicates that the majority of customers have relatively limited engagement with the bank's products, while only a small number utilize multiple banking services. The <b>NumOfProducts</b> feature may therefore provide valuable insights into customer behavior and churn prediction.
# </p>
#
# </div>

# %%
df.groupby(["Gender"])["NumOfProducts"].value_counts(normalize = True).plot(kind="barh", figsize=(7,7))
# Out:
# <Axes: ylabel='Gender,NumOfProducts'>

# %% [markdown]
# <div style="border-radius: 5px; font-family: cursive; border: 3px solid #007A33; background: #F6FFF9; color: black; font-size: 14px; padding: 15px;">
#
# <p style="color: darkgreen; font-weight: bold; font-size: 16px;">
#  Gender-Based Customer Characteristics
# </p>
#
# <p style="line-height:1.7;">
# The analysis shows that male and female customers exhibit similar distributions across key characteristics. Both genders display comparable patterns in the number of banking products used and the proportion of active members.
# </p>
#
# <p style="line-height:1.7;">
# This suggests that customer engagement is relatively consistent across genders, indicating that <b>Gender</b> alone may have limited predictive power and should be evaluated alongside other demographic and financial features.
# </p>
#
# </div>

# %%
df.groupby(["Gender"])["IsActiveMember"].value_counts(normalize = True).plot(kind="barh", figsize=(7,7))
# Out:
# <Axes: ylabel='Gender,IsActiveMember'>

# %%
plt.title("Active member VS Not Active Member")
plt.ylabel("Count")
ax =sns.countplot(x=df.IsActiveMember, hue=df.Exited)
for p in ax.containers:
    ax.bar_label(p)

# %% [markdown]
# <div style="border-radius: 5px; font-family: cursive; border: 3px solid #007A33; background: #F6FFF9; color: black; font-size: 14px; padding: 15px;">
#
# <p style="color: darkgreen; font-weight: bold; font-size: 16px;">
#  Customer Activity Status
# </p>
#
# <p style="line-height:1.7;">
# The analysis indicates that the majority of both active and inactive members remain customers of the bank. In each group, retained customers (Exited = 0) substantially outnumber those who have closed their accounts.
# </p>
#
# <p style="line-height:1.7;">
# Although customer retention is generally high across both groups, membership activity may still contribute to churn prediction when combined with other demographic and financial features in machine learning models.
# </p>
#
# </div>

# %%
plt.title("Credit Card according to Tenure")
plt.ylabel("Count")
ax =sns.countplot(x=df.Tenure, hue=df.HasCrCard)
for p in ax.containers:
    ax.bar_label(p)

# %%
plt.title("Gender according to Tenure")
plt.ylabel("Count")
ax =sns.countplot(x=df.Tenure, hue=df.Gender)
for p in ax.containers:
    ax.bar_label(p)

# %%
plt.title("Exited according to Geography")
plt.ylabel("Count")
ax =sns.countplot(x=df.Geography, hue=df.Exited)
for p in ax.containers:
    ax.bar_label(p)

# %%
plt.title("Exited according to Gender")
plt.ylabel("Count")
ax =sns.countplot(x=df.Gender, hue=df.Exited)
for p in ax.containers:
    ax.bar_label(p)

# %% [markdown]
# <div style="border-radius: 5px; font-family: cursive; border: 3px solid #007A33; background: #F6FFF9; color: black; font-size: 14px; padding: 15px;">
#
# <p style="color: darkgreen; font-weight: bold; font-size: 16px;">
#  Customer Retention by Gender
# </p>
#
# <p style="line-height:1.7;">
# The gender-based analysis indicates that a slightly higher proportion of <b>female customers</b> remain with the bank compared to <b>male customers</b>. Overall, customer retention is high for both genders, with retained customers significantly outnumbering those who have exited.
# </p>
#
# <p style="line-height:1.7;">
# This suggests that while <b>Gender</b> may exhibit some association with customer retention, its predictive value is likely stronger when combined with other customer demographic, financial, and behavioral features.
# </p>
#
# </div>

# %%
ax = sns.countplot(x=df["HasCrCard"])
ax.bar_label(ax.containers[0]);

# %% [markdown]
# <div style="border-radius: 5px; font-family: cursive; border: 3px solid #007A33; background: #F6FFF9; color: black; font-size: 14px; padding: 15px;">
#
# <p style="color: darkgreen; font-weight: bold; font-size: 16px;">
#  Credit Card Ownership
# </p>
#
# <p style="line-height:1.7;">
# The distribution of credit card ownership indicates that the majority of customers possess a <b>credit card</b>, while a smaller proportion of customers do not.
# </p>
#
# <p style="line-height:1.7;">
# This suggests that credit card ownership is common among the bank's customers. Although <b>HasCrCard</b> may provide useful information, its impact on customer churn should be evaluated alongside other demographic, financial, and behavioral variables within predictive models.
# </p>
#
# </div>

# %%
ax = sns.countplot(x=df["Exited"])
ax.bar_label(ax.containers[0]);

# %% [markdown]
# <div style="border-radius: 5px; font-family: cursive; border: 3px solid #007A33; background: #F6FFF9; color: black; font-size: 14px; padding: 15px;">
#
# <p style="color: darkgreen; font-weight: bold; font-size: 16px;">
#  Customer Churn Distribution
# </p>
#
# <p style="line-height:1.7;">
# The target variable distribution shows that the number of customers who <b>maintain their relationship with the bank</b> is significantly higher than the number of customers who have exited.
# </p>
#
# <p style="line-height:1.7;">
# This indicates an imbalance between the retained and churned customer classes. Therefore, evaluation metrics such as <b>precision, recall, F1-score, and ROC-AUC</b> should be considered in addition to accuracy when assessing classification model performance.
# </p>
#
# </div>

# %%
plt.figure(figsize=(20, 20))
sns.heatmap(df.corr(numeric_only=True), annot=True, vmin=-1, vmax=1, cmap="coolwarm")
plt.show()

# %% [markdown]
# <div style="border-radius: 5px; font-family: cursive; border: 3px solid #007A33; background: #F6FFF9; color: black; font-size: 14px; padding: 15px;">
#
# <p style="color: darkgreen; font-weight: bold; font-size: 16px;">
#  Feature Correlation Analysis
# </p>
#
# <p style="line-height:1.7;">
# The correlation analysis reveals that most numerical features have <b>weak linear relationships</b> with each other. The correlation coefficients are generally close to zero, indicating that the variables provide relatively independent information.
# </p>
#
# <p style="line-height:1.7;">
# This low level of correlation suggests that there is limited multicollinearity among the features. Therefore, most variables can contribute unique information to machine learning models without significant redundancy.
# </p>
#
# </div>

# %%
plt.figure(figsize=(8, 10))
ax=df.corr(numeric_only = True)["Exited"].sort_values().drop("Exited").plot(kind="barh")
ax.bar_label(ax.containers[0], fmt="%.2f")
plt.show()

# %%
numeric_columns = df.select_dtypes(include=['number']).drop(columns=['Exited', 'HasCrCard', 'IsActiveMember'])

ncols = 3
num_plots = len(numeric_columns.columns)
nrows = (num_plots - 1) // ncols + 1

fig, axes = plt.subplots(nrows, ncols, figsize=(15, 5 * nrows))

for i, column in enumerate(numeric_columns.columns):
    row = i // ncols
    col = i % ncols
    sns.boxplot(data=df, x='Exited', y=column, ax=axes[row, col])
    axes[row, col].set_title(f'Boxplot of {column}')

for i in range(num_plots, nrows * ncols):
    fig.delaxes(axes.flatten()[i])

plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="border-radius: 5px; font-family: cursive; border: 3px solid #007A33; background: #F6FFF9; color: black; font-size: 14px; padding: 15px;">
#
# <p style="color: darkgreen; font-weight: bold; font-size: 16px;">
#  Outlier Analysis
# </p>
#
# <p style="line-height:1.7;">
# The boxplot analysis highlights the presence of extreme values across several numerical features. These observations represent potential outliers within the dataset.
# </p>
#
# <p style="line-height:1.7;">
# Since Artificial Neural Networks (ANNs) are generally capable of learning complex patterns and this project focuses on maintaining realistic real-world customer data characteristics, no outlier removal or transformation was applied.
# </p>
#
# <p style="line-height:1.7;">
# Keeping these values allows the model to learn from the natural variability present in customer financial behavior while preserving the original data distribution.
# </p>
#
# </div>

# %% [markdown]
# <h1><p><center style="background: linear-gradient(to right,white,green);color: transparent;font-family: Gabriola;color: navy;font-size: 80%;text-align: center;border-radius: 10px 70px">
#      Deep Learning
#
# </center></p></h1>

# %% [markdown]
# <h1><p><center style="background: linear-gradient(to right,white,green);color: transparent;font-family: Gabriola;color: navy;font-size: 80%;text-align: center;border-radius: 10px 70px">
#    Preprocessing of Data
#
# </center></p></h1>

# %%
df.select_dtypes(include=['object']).columns
# Out:
# Index(['Geography', 'Gender'], dtype='object')

# %%
cat_columns = df.select_dtypes(include=['object']).columns

df = pd.get_dummies(df, columns=cat_columns)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CreditScore        10000 non-null  int64
#  1   Age                10000 non-null  int64
#  2   Tenure             10000 non-null  int64
#  3   Balance            10000 non-null  float64
#  4   NumOfProducts      10000 non-null  int64
#  5   HasCrCard          10000 non-null  int64
#  6   IsActiveMember     10000 non-null  int64
#  7   EstimatedSalary    10000 non-null  float64
#  8   Exited             10000 non-null  int64
#  9   Geography_France   10000 non-null  bool
#  10  Geography_Germany  10000 non-null  bool
#  11  Geography_Spain    10000 non-null  bool
#  12  Gender_Female      10000 non-null  bool
#  13  Gender_Male        10000 non-null  bool
# dtypes: bool(5), float64(2), int64(7)
# memory usage: 752.1 KB

# %% [markdown]
# <div style="border-radius: 5px; font-family: cursive; border: 3px solid #007A33; background: #F6FFF9; color: black; font-size: 14px; padding: 15px;">
#
# <p style="color: darkgreen; font-weight: bold; font-size: 16px;">
#  Categorical Feature Encoding
# </p>
#
# <p style="line-height:1.7;">
# The categorical variables in the dataset were transformed using <b>One-Hot Encoding</b> with the <b>get_dummies()</b> method. This process converts categorical values into numerical representations that can be effectively used by machine learning and deep learning algorithms.
# </p>
#
# <p style="line-height:1.7;">
# After encoding, the dataset contains <b>13 input features</b> and <b>1 target variable</b> (<b>Exited</b>), providing a suitable structure for training the classification model.
# </p>
#
# </div>

# %%
X = df.drop("Exited", axis = 1)
y = df["Exited"]

# %%
seed=42

# %%
X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    y,
                                                    stratify=y, 
                                                    test_size=0.2, random_state=seed)

X_train, X_val, y_train, y_val = train_test_split(X_train, 
                                                    y_train, 
                                                    stratify=y_train,
                                                    test_size=0.1, random_state=seed)

# %%
print(y.value_counts(normalize=True))
print()
print(y_train.value_counts(normalize=True))
print()
print(y_test.value_counts(normalize=True))
print()
print(y_val.value_counts(normalize=True))
# Out:
# Exited
# 0   0.796
# 1   0.204
# Name: proportion, dtype: float64
#
# Exited
# 0   0.796
# 1   0.204
# Name: proportion, dtype: float64
#
# Exited
# 0   0.796
# 1   0.203
# Name: proportion, dtype: float64
#
# Exited
# 0   0.796
# 1   0.204
# Name: proportion, dtype: float64

# %%
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_val = scaler.transform(X_val)
X_test = scaler.transform(X_test)

# %%
print("Shape of train :", X_train.shape)
print("Shape of validation :", X_val.shape)
print("Shape of test :", X_test.shape)
# Out:
# Shape of train : (7200, 13)
# Shape of validation : (800, 13)
# Shape of test : (2000, 13)

# %% [markdown]
# <h1><p><center style="background: linear-gradient(to right,white,green);color: transparent;font-family: Gabriola;color: navy;font-size: 80%;text-align: center;border-radius: 10px 70px">
#     Modelling & Model Performance
# </center></p></h1>

# %%
batch_size = 64

# %%
model = Sequential()

model.add(Dense(15, activation="relu", input_dim=X_train.shape[1])) 
model.add(Dense(10, activation="relu"))
model.add(Dense(6, activation="relu"))
model.add(Dense(4, activation="relu"))
model.add(Dense(1, activation="sigmoid")) 

model.compile(optimizer="adam", loss="binary_crossentropy", metrics=["Recall"])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 15)                210
#
#  dense_1 (Dense)             (None, 10)                160
#
#  dense_2 (Dense)             (None, 6)                 66
#
#  dense_3 (Dense)             (None, 4)                 28
#
#  dense_4 (Dense)             (None, 1)                 5
#
# ...
# Total params: 469 (1.83 KB)
# Trainable params: 469 (1.83 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.fit(x=X_train,
          y=y_train,
          validation_data=(X_val, y_val),
          batch_size=batch_size,
          epochs=500)
# Out:
# Epoch 1/500
# 113/113 [==============================] - 6s 6ms/step - loss: 0.5751 - recall: 0.0225 - val_loss: 0.4881 - val_recall: 0.0000e+00
# Epoch 2/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4758 - recall: 0.0000e+00 - val_loss: 0.4658 - val_recall: 0.0000e+00
# Epoch 3/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4597 - recall: 0.0000e+00 - val_loss: 0.4549 - val_recall: 0.0000e+00
# Epoch 4/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4504 - recall: 0.0000e+00 - val_loss: 0.4464 - val_recall: 0.0000e+00
# Epoch 5/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4441 - recall: 0.0000e+00 - val_loss: 0.4395 - val_recall: 0.0000e+00
# Epoch 6/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.4386 - recall: 0.0000e+00 - val_loss: 0.4335 - val_recall: 0.0000e+00
# Epoch 7/500
# ...

# %%
loss_df = pd.DataFrame(model.history.history)
loss_df.head()
# Out:
#    loss  recall  val_loss  val_recall
# 0 0.575   0.022     0.488       0.000
# 1 0.476   0.000     0.466       0.000
# 2 0.460   0.000     0.455       0.000
# 3 0.450   0.000     0.446       0.000
# 4 0.444   0.000     0.439       0.000

# %% [markdown]
# <h1><p><center style="background: linear-gradient(to right,white,green);color: transparent;font-family: Gabriola;color: navy;font-size: 80%;text-align: center;border-radius: 10px 70px">
#    Evaluate The Model
# </center></p></h1>

# %%
loss_df.plot()
plt.show()

# %%
model.evaluate(X_test, y_test, verbose=0)
# Out:
# [0.34825417399406433, 0.5356265306472778]

# %%
loss, recall = model.evaluate(X_test, y_test, verbose=0)
print("loss: ", loss)
print("recall: ", recall)
# Out:
# loss:  0.34825417399406433
# recall:  0.5356265306472778

# %%
y_pred = model.predict(X_test) > 0.5
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# 63/63 [==============================] - 0s 1ms/step
# [[1499   94]
#  [ 189  218]]
#               precision    recall  f1-score   support
#
#            0       0.89      0.94      0.91      1593
#            1       0.70      0.54      0.61       407
#
#     accuracy                           0.86      2000
#    macro avg       0.79      0.74      0.76      2000
# weighted avg       0.85      0.86      0.85      2000

# %%
y_pred_proba = model.predict(X_test)
RocCurveDisplay.from_predictions(y_test, y_pred_proba)
# Out:
# 63/63 [==============================] - 0s 1ms/step

# %%
# from scikitplot.metrics import plot_roc, precision_recall_curve,average_precision_score
y_pred_proba = model.predict(X_test)

precision, recall, _ = precision_recall_curve(y_test, y_pred_proba)

average_precision = average_precision_score(y_test, y_pred_proba)

plt.plot(recall, precision, color='blue', lw=2, label=f'AP = {average_precision:.2f}')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend(loc='best')
plt.show()
# Out:
# 63/63 [==============================] - 0s 1ms/step

# %%
y_pred = model.predict(X_test) > 0.5
model_AP = average_precision_score(y_test, y_pred)
model_precision = precision_score(y_test, y_pred)
model_recall = recall_score(y_test, y_pred)
# Out:
# 63/63 [==============================] - 0s 1ms/step

# %% [markdown]
# <a href="#part_2" class="btn btn-danger btn-lg active" role="button" aria-pressed="true" style="color:white;">Part - 2</a>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %% [markdown]
# <h1><p><center style="background: linear-gradient(to right,white,green);color: transparent;font-family: Gabriola;color: navy;font-size: 80%;text-align: center;border-radius: 10px 70px">
#       Increase The Learning Rate and Observe The Results
# </center></p></h1>

# %% [markdown]
# ![learning_rate](https://miro.medium.com/v2/resize:fit:1200/0*K0ltbXIgtNLEXsXN.png)
# [Credit](https://www.google.com/url?sa=i&url=https%3A%2F%2Fmedium.com%2Foctavian-ai%2Fhow-to-use-the-learning-rate-finder-in-tensorflow-126210de9489&psig=AOvVaw2GiCBkU0T8pc8lbeGTmzhi&ust=1699876013893000&source=images&cd=vfe&opi=89978449&ved=0CBQQjhxqFwoTCKDF6OKxvoIDFQAAAAAdAAAAABAD)

# %% [markdown]
# <a href="#part_2" class="btn btn-danger btn-lg active" role="button" aria-pressed="true" style="color:white;">Part - 2</a>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %%
from tensorflow.keras.optimizers import Adam
learning_rate = 0.003

# %%
model3 = Sequential()

model3.add(Dense(15, activation="relu", input_dim=X_train.shape[1]))
model3.add(Dense(10, activation="relu"))
model3.add(Dense(6, activation="relu"))
model3.add(Dense(4, activation="relu"))
model3.add(Dense(1, activation="sigmoid")) 

opt=Adam(learning_rate = learning_rate)
model3.compile(optimizer=opt, loss="binary_crossentropy", metrics=["Recall"])

# %%
model3.fit(
    x=X_train,
    y=y_train,
    validation_data=(X_val, y_val),
    batch_size=batch_size,
    epochs=500)
# Out:
# Epoch 1/500
# 113/113 [==============================] - 3s 6ms/step - loss: 0.6791 - recall: 0.3463 - val_loss: 0.6181 - val_recall: 0.6012
# Epoch 2/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.6431 - recall: 0.6230 - val_loss: 0.5968 - val_recall: 0.6810
# Epoch 3/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.6208 - recall: 0.6817 - val_loss: 0.5628 - val_recall: 0.7055
# Epoch 4/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.6000 - recall: 0.6823 - val_loss: 0.4948 - val_recall: 0.6871
# Epoch 5/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.5772 - recall: 0.7301 - val_loss: 0.5641 - val_recall: 0.8344
# Epoch 6/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.5551 - recall: 0.7410 - val_loss: 0.4676 - val_recall: 0.7546
# Epoch 7/500
# ...

# %%
# loss_df = pd.DataFrame(model3.history.history)
# loss_df.plot()
pd.DataFrame(model3.history.history).plot()
plt.show()

# %%
loss, recall = model3.evaluate(X_test, y_test, verbose=0)
print("loss: ", loss)
print("recall: ", recall)
# Out:
# loss:  0.45977020263671875
# recall:  0.7567567825317383

# %%
y_pred = model3.predict(X_test) > 0.5 
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# 63/63 [==============================] - 0s 1ms/step
# [[1258  335]
#  [  99  308]]
#               precision    recall  f1-score   support
#
#            0       0.93      0.79      0.85      1593
#            1       0.48      0.76      0.59       407
#
#     accuracy                           0.78      2000
#    macro avg       0.70      0.77      0.72      2000
# weighted avg       0.84      0.78      0.80      2000

# %%
y_pred_proba = model3.predict(X_test)

precision, recall, _ = precision_recall_curve(y_test, y_pred_proba)

average_precision = average_precision_score(y_test, y_pred_proba)

plt.plot(recall, precision, color='blue', lw=2, label=f'AP = {average_precision:.2f}')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend(loc='best')
plt.show()
# Out:
# 63/63 [==============================] - 0s 1ms/step

# %%
y_pred = model3.predict(X_test) > 0.5
model3_AP = average_precision_score(y_test, y_pred)
model3_precision = precision_score(y_test, y_pred)
model3_recall = recall_score(y_test, y_pred)
# Out:
# 63/63 [==============================] - 0s 2ms/step

# %% [markdown]
# <a id="1"></a>
# # <p style="background: linear-gradient(to right,white,green);color: transparent;font-family: Gabriola;color: navy;font-size: 80%;text-align: center;border-radius: 10px 70px">Add Dropout Layer</p>
# </div>

# %% [markdown]
# ![dropout.png](https://i.stack.imgur.com/SbXq1.jpg)
# [Credit](https://www.google.com/url?sa=i&url=https%3A%2F%2Fstackoverflow.com%2Fquestions%2F34597316%2Fwhy-input-is-scaled-in-tf-nn-dropout-in-tensorflow&psig=AOvVaw1l_917bIGSEasDy2uybjlj&ust=1699876094112000&source=images&cd=vfe&opi=89978449&ved=0CBQQjhxqFwoTCNDmtomyvoIDFQAAAAAdAAAAABAI)

# %%
model4 = Sequential()

model4.add(Dense(15, activation="relu", input_dim=X_train.shape[1]))
model4.add(Dropout(0.5))

model4.add(Dense(10, activation="relu"))
model4.add(Dropout(0.5))

model4.add(Dense(6, activation="relu"))
model4.add(Dropout(0.5))

model4.add(Dense(4, activation="relu"))
model4.add(Dropout(0.5))

model4.add(Dense(1, activation="sigmoid")) 

opt=Adam(learning_rate = learning_rate)
model4.compile(optimizer=opt, loss="binary_crossentropy", metrics=["Recall"])

# %%
model4.fit(
    x=X_train,
    y=y_train,
    validation_data=(X_val, y_val),
    batch_size=batch_size,
    epochs=500)
# Out:
# Epoch 1/500
# 113/113 [==============================] - 3s 6ms/step - loss: 0.6979 - recall: 0.8057 - val_loss: 0.6971 - val_recall: 1.0000
# Epoch 2/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.6906 - recall: 0.9046 - val_loss: 0.6944 - val_recall: 0.9509
# Epoch 3/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.6870 - recall: 0.8609 - val_loss: 0.6980 - val_recall: 0.9325
# Epoch 4/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.6867 - recall: 0.8214 - val_loss: 0.6972 - val_recall: 0.8344
# Epoch 5/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.6842 - recall: 0.6517 - val_loss: 0.6922 - val_recall: 0.8957
# Epoch 6/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.6854 - recall: 0.5147 - val_loss: 0.6819 - val_recall: 0.7485
# Epoch 7/500
# ...

# %%
pd.DataFrame(model4.history.history).plot()
plt.show()

# %%
loss, recall = model4.evaluate(X_test, y_test, verbose=0)
print("loss: ", loss)
print("recall: ", recall)
# Out:
# loss:  0.5559669733047485
# recall:  0.764127790927887

# %%
y_pred = model4.predict(X_test) > 0.5
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# 63/63 [==============================] - 0s 1ms/step
# [[1219  374]
#  [  96  311]]
#               precision    recall  f1-score   support
#
#            0       0.93      0.77      0.84      1593
#            1       0.45      0.76      0.57       407
#
#     accuracy                           0.77      2000
#    macro avg       0.69      0.76      0.70      2000
# weighted avg       0.83      0.77      0.78      2000

# %%
y_pred_proba = model4.predict(X_test)

precision, recall, _ = precision_recall_curve(y_test, y_pred_proba)

model4_average_precision = average_precision_score(y_test, y_pred_proba)

plt.plot(recall, precision, color='blue', lw=2, label=f'AP = {model4_average_precision:.2f}')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend(loc='best')
plt.show()
# Out:
# 63/63 [==============================] - 0s 1ms/step

# %%
y_pred = model4.predict(X_test) > 0.5
model4_AP = average_precision_score(y_test, y_pred)
model4_precision = precision_score(y_test, y_pred)
model4_recall = recall_score(y_test, y_pred)
# Out:
# 63/63 [==============================] - 0s 2ms/step

# %% [markdown]
# <a id="1"></a>
# # <p style="background: linear-gradient(to right,white,green);color: transparent;font-family: Gabriola;color: navy;font-size: 80%;text-align: center;border-radius: 10px 70px">Add Early Stop</p>
# </div>

# %% [markdown]
# ![earlystop.png](https://miro.medium.com/v2/resize:fit:1242/1*W368qtCQlCYmt6YlwIYnJg.png)
# [Credit](https://www.google.com/url?sa=i&url=https%3A%2F%2Ftowardsdatascience.com%2Fthe-million-dollar-question-when-to-stop-training-deep-learning-models-fa9b488ac04d&psig=AOvVaw1sNjyOBI0EZGAIZBAV5dDJ&ust=1699876191913000&source=images&cd=vfe&opi=89978449&ved=0CBQQjhxqFwoTCJCV0LqyvoIDFQAAAAAdAAAAABAD)

# %%
early_stop = EarlyStopping(
    monitor="val_loss", mode="min", verbose=1, patience=15, restore_best_weights=True)

# %%
model5 = Sequential()

model5.add(Dense(15, activation="relu", input_dim=X_train.shape[1])) 
model5.add(Dense(10, activation="relu"))
model5.add(Dense(6, activation="relu"))
model5.add(Dense(4, activation="relu"))
model5.add(Dense(1, activation="sigmoid"))


opt=Adam(learning_rate = learning_rate)
model5.compile(optimizer=opt, loss="binary_crossentropy", metrics=["Recall"])

# %%
model5.fit(
    x=X_train,
    y=y_train,
    validation_data=(X_val, y_val),
    batch_size=batch_size,
    epochs=500,
    callbacks=[early_stop])
# Out:
# Epoch 1/500
# 113/113 [==============================] - 2s 6ms/step - loss: 0.6768 - recall: 0.7669 - val_loss: 0.7434 - val_recall: 0.6994
# Epoch 2/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.6446 - recall: 0.6817 - val_loss: 0.6756 - val_recall: 0.6748
# Epoch 3/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.6211 - recall: 0.6851 - val_loss: 0.6422 - val_recall: 0.6933
# Epoch 4/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.6043 - recall: 0.6742 - val_loss: 0.5904 - val_recall: 0.6503
# Epoch 5/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.5888 - recall: 0.6892 - val_loss: 0.5767 - val_recall: 0.7301
# Epoch 6/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.5697 - recall: 0.6946 - val_loss: 0.5601 - val_recall: 0.7485
# Epoch 7/500
# ...

# %% [markdown]
# <a href="#part_2" class="btn btn-danger btn-lg active" role="button" aria-pressed="true" style="color:white;">Part - 2</a>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %%
pd.DataFrame(model5.history.history).plot()
plt.show()

# %%
loss, recall = model5.evaluate(X_test, y_test, verbose=0)
print("loss: ", loss)
print("recall: ", recall)
# Out:
# loss:  0.41260790824890137
# recall:  0.6584766507148743

# %%
y_pred = model5.predict(X_test) > 0.5
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# 63/63 [==============================] - 0s 1ms/step
# [[1397  196]
#  [ 139  268]]
#               precision    recall  f1-score   support
#
#            0       0.91      0.88      0.89      1593
#            1       0.58      0.66      0.62       407
#
#     accuracy                           0.83      2000
#    macro avg       0.74      0.77      0.75      2000
# weighted avg       0.84      0.83      0.84      2000

# %%
y_pred_proba = model5.predict(X_test)

precision, recall, _ = precision_recall_curve(y_test, y_pred_proba)

average_precision = average_precision_score(y_test, y_pred_proba)

plt.plot(recall, precision, color='blue', lw=2, label=f'AP = {average_precision:.2f}')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend(loc='best')
plt.show()
# Out:
# 63/63 [==============================] - 0s 1ms/step

# %%
y_pred = model5.predict(X_test) > 0.5
model5_AP = average_precision_score(y_test, y_pred)
model5_precision = precision_score(y_test, y_pred)
model5_recall = recall_score(y_test, y_pred)
# Out:
# 63/63 [==============================] - 0s 1ms/step

# %% [markdown]
# <a id="1"></a>
# # <p style="background: linear-gradient(to right,white,green);color: transparent;font-family: Gabriola;color: navy;font-size: 80%;text-align: center;border-radius: 10px 70px">Optuna </p>
# </div>

# %%
import optuna

# %%
trial_metric = "Recall"
batch_size = 64


def create_model(trial): # the part where the metric ranges in the compile part of the model are determined and the model is built
    # Some hyperparameters we want to optimize # 
    n_units1 = trial.suggest_int("n_units1", 2, 128) # number of neurons
    n_units2 = trial.suggest_int("n_units2", 2, 128) 
    n_units3 = trial.suggest_int("n_units3", 2, 128)
    n_units4 = trial.suggest_int("n_units4", 2, 128)
    optimizer = trial.suggest_categorical("optimizer", [Adam, Adadelta, RMSprop, Nadam])
    learning_rate = trial.suggest_loguniform("learning_rate", 1e-5, 1.3e-1)

    model = Sequential()
    model.add(Dense(n_units1, input_dim=X_train.shape[1], activation="relu"))
    model.add(Dense(n_units2, activation="relu")) # hidden layer
    model.add(Dense(n_units3, activation="relu"))
    model.add(Dense(n_units4, activation="relu"))
    model.add(Dense(1, activation="sigmoid")) # output.
    model.compile(
        loss="binary_crossentropy",
        optimizer=optimizer(learning_rate=learning_rate),
        metrics=[trial_metric],)
    return model


def objective(trial): # contains fit
    model = create_model(trial) # called the created model.
    w0 = trial.suggest_loguniform("w0", 0.01, 5) # class_weight
    w1 = trial.suggest_loguniform("w1", 0.01, 5)
    model.fit(
        X_train,
        y_train,
        validation_data=(X_val, y_val),
        batch_size=batch_size,
        epochs=100,
        callbacks=[early_stop],
        class_weight={0: w0, 1: w1},
        verbose=0,)
    score = model.evaluate(X_test, y_test, verbose=0)[1]
    return score

# %%
study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=10)
study.best_params
# Out:
# [I 2023-11-12 20:58:23,323] A new study created in memory with name: no-name-67c27280-3a72-45b5-a19f-0e92c67a5ecb
# Restoring model weights from the end of the best epoch: 34.
# Epoch 49: early stopping
# [I 2023-11-12 20:58:45,758] Trial 0 finished with value: 0.0 and parameters: {'n_units1': 71, 'n_units2': 6, 'n_units3': 74, 'n_units4': 37, 'optimizer': <class 'keras.src.optimizers.adadelta.Adadelta'>, 'learning_rate': 0.0014298335966158456, 'w0': 0.6307073723159795, 'w1': 0.04537726363454021}. Best is trial 0 with value: 0.0.
# [I 2023-11-12 20:59:29,214] Trial 1 finished with value: 0.0 and parameters: {'n_units1': 82, 'n_units2': 59, 'n_units3': 86, 'n_units4': 41, 'optimizer': <class 'keras.src.optimizers.adadelta.Adadelta'>, 'learning_rate': 1.987215701818977e-05, 'w0': 1.1745804421429515, 'w1': 0.09511741951161092}. Best is trial 0 with value: 0.0.
# ...

# %%
unit1, unit2, unit3,unit4, optimizer, lr, w0, w1 = (
    study.best_params["n_units1"],
    study.best_params["n_units2"],
    study.best_params["n_units3"],
    study.best_params["n_units4"],
    study.best_params["optimizer"],
    study.best_params["learning_rate"],
    study.best_params["w0"],
    study.best_params["w1"])


model7 = Sequential()

model7.add(Dense(unit1, activation="relu", input_dim=X_train.shape[1])) 
model7.add(Dense(unit2, activation="relu"))
model7.add(Dense(unit3, activation="relu"))
model7.add(Dense(unit4, activation="relu"))
model7.add(Dense(1, activation="sigmoid"))

opt = optimizer(learning_rate=lr)
model7.compile(optimizer=opt, loss="binary_crossentropy", metrics=["Recall"])

model7.fit(
    X_train,
    y_train,
    validation_data=(X_val, y_val),
    batch_size=64,
    epochs=500,
    callbacks=[early_stop],
    class_weight={0: w0, 1: w1},
    verbose=1,
)

#loss has binary_crossentropy. Because we are working in binary.
# If there was multiclass, we would be working with categorical_crossentropy.
# Out:
# Epoch 1/500
# 113/113 [==============================] - 2s 6ms/step - loss: 0.0571 - recall: 1.0000 - val_loss: 1.0486 - val_recall: 1.0000
# Epoch 2/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.0533 - recall: 0.9748 - val_loss: 1.2647 - val_recall: 1.0000
# Epoch 3/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.0517 - recall: 0.9625 - val_loss: 0.8468 - val_recall: 0.9509
# Epoch 4/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.0482 - recall: 0.9455 - val_loss: 0.9522 - val_recall: 0.9509
# Epoch 5/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.0463 - recall: 0.9380 - val_loss: 0.6481 - val_recall: 0.9264
# Epoch 6/500
# 113/113 [==============================] - 0s 4ms/step - loss: 0.0452 - recall: 0.9434 - val_loss: 1.3178 - val_recall: 0.9755
# Epoch 7/500
# ...

# %%
# pd.DataFrame(model7.history.history).plot()
# plt.show()
y_pred = (model7.predict(X_test) > 0.5).astype("int32")
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# 63/63 [==============================] - 0s 2ms/step
# [[1053  540]
#  [  69  338]]
#               precision    recall  f1-score   support
#
#            0       0.94      0.66      0.78      1593
#            1       0.38      0.83      0.53       407
#
#     accuracy                           0.70      2000
#    macro avg       0.66      0.75      0.65      2000
# weighted avg       0.83      0.70      0.72      2000

# %%
y_pred_proba = model7.predict(X_test)

precision, recall, _ = precision_recall_curve(y_test, y_pred_proba)

average_precision = average_precision_score(y_test, y_pred_proba)

plt.plot(recall, precision, color='blue', lw=2, label=f'AP = {average_precision:.2f}')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend(loc='best')
plt.show()
# Out:
# 63/63 [==============================] - 0s 1ms/step

# %%
y_pred = model7.predict(X_test) > 0.5
model7_AP = average_precision_score(y_test, y_pred)
model7_precision = precision_score(y_test, y_pred)
model7_recall = recall_score(y_test, y_pred)
# Out:
# 63/63 [==============================] - 0s 1ms/step

# %% [markdown]
# <a id="1"></a>
# # <p style="background: linear-gradient(to right,white,green);color: transparent;font-family: Gabriola;color: navy;font-size: 80%;text-align: center;border-radius: 10px 70px">Compare of Models</p>
# </div>

# %%
compare= pd.DataFrame({"Methods": ["Non Class-weight", "Class-weight",  "Class-weight,learning_rate",
                                 "Class-weight,learning_rate,dropout","Class-weight,Learning_rate,Earlystop-val_loss", 
                                   "Class-weight,Learning_rate,Earlystop-val_recall","Optuna"],
                       "Precision": [model_precision, model2_precision, model3_precision, model4_precision,
                                     model5_precision, model6_precision, model7_precision],
                       "Recall": [model_recall, model2_recall, model3_recall, model4_recall,
                                  model5_recall, model6_recall, model7_recall],
                       "AP": [model_AP, model2_AP, model3_AP, model4_AP,
                              model5_AP,model6_AP,model7_AP]})

compare
# Out:
#                                            Methods  Precision  Recall    AP
# 0                                 Non Class-weight      0.699   0.536 0.469
# 1                                     Class-weight      0.445   0.789 0.394
# 2                       Class-weight,learning_rate      0.479   0.757 0.412
# 3               Class-weight,learning_rate,dropout      0.454   0.764 0.395
# 4    Class-weight,Learning_rate,Earlystop-val_loss      0.578   0.658 0.450
# 5  Class-weight,Learning_rate,Earlystop-val_recall      0.244   0.840 0.238
# 6                                           Optuna      0.385   0.830 0.354

# %%
plt.figure(figsize=(14,10))
plt.subplot(311)
compare = compare.sort_values(by="Precision", ascending=False)
ax=sns.barplot(x="Precision", y="Methods", data=compare, palette="Blues_d")
ax.bar_label(ax.containers[0],fmt="%.3f")

plt.subplot(312)
compare = compare.sort_values(by="Recall", ascending=False)
ax=sns.barplot(x="Recall", y="Methods", data=compare, palette="Blues_d")
ax.bar_label(ax.containers[0],fmt="%.3f")

plt.subplot(313)
compare = compare.sort_values(by="AP", ascending=False)
ax=sns.barplot(x="AP", y="Methods", data=compare, palette="Blues_d")
ax.bar_label(ax.containers[0],fmt="%.3f")
plt.show();

# %% [markdown]
# <div style="border-radius: 5px; font-family: cursive; border: 3px solid #007A33; background: #F6FFF9; color: black; font-size: 14px; padding: 15px;">
#
# <p style="color: darkgreen; font-weight: bold; font-size: 16px;">
#  Deep Learning Model Summary
# </p>
#
# <p style="line-height:1.7;">
# In this study, seven different Artificial Neural Network (ANN) models were developed and evaluated for customer churn prediction. Each model consisted of <b>three hidden layers</b> and was designed to investigate the impact of different optimization strategies on classification performance.
# </p>
#
# <p style="color:#333; font-weight:bold;">🔹 Model Configurations</p>
#
# <ul style="margin-left:15px; line-height:1.7;">
#
# <li><b>Model 1:</b> Baseline ANN without class weighting.</li>
#
# <li><b>Model 2:</b> ANN with class-weight adjustment to address class imbalance.</li>
#
# <li><b>Model 3:</b> Class-weight optimization combined with learning rate tuning.</li>
#
# <li><b>Model 4:</b> Class-weight, learning rate, and dropout regularization.</li>
#
# <li><b>Model 5:</b> Class-weight, learning rate, and Early Stopping based on validation loss.</li>
#
# <li><b>Model 6:</b> Class-weight, learning rate, and Early Stopping based on validation recall.</li>
#
# <li><b>Model 7:</b> Hyperparameter optimization using Optuna.</li>
#
# </ul>
#
# <p style="line-height:1.7;">
# The experiments evaluated the effect of different hyperparameter strategies, including class weights, learning rates, dropout regularization, and early stopping criteria. Since the dataset contains an imbalanced target variable, improving the model's ability to identify churned customers was a key objective.
# </p>
#
# <p style="line-height:1.7;">
# The results showed that the configuration using <b>Class-weight + Learning Rate Optimization + Early Stopping based on validation loss</b> achieved the best balance between predictive performance and churn detection capability. This approach improved recall while maintaining a reasonable trade-off between precision and recall, leading to a stronger <b>F1-score</b> performance.
# </p>
#
# <p style="line-height:1.7;">
# Therefore, <b>Model 5</b> was selected as the final ANN model. The complete workflow included model training, feature scaling preservation, model saving, and prediction generation from the saved model state.
# </p>
#
# <p style="line-height:1.7;">
# Overall, the deep learning approach successfully addressed the binary classification problem and demonstrated the importance of systematic hyperparameter tuning for improving model performance on imbalanced customer churn datasets.
# </p>
#
# <p style="line-height:1.7;">
# Additionally, ANN models showed robustness when handling extreme values. Since the objective was to preserve realistic customer behavior patterns, outliers were retained rather than removed during preprocessing.
# </p>
#
# </div>

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Banking Churn Prediction - Deep Learning Project</title>
#     <style>
#         * {
#             margin: 0;
#             padding: 0;
#             box-sizing: border-box;
#         }
#
#         body {
#             font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif;
#             background: #f0f4f8;
#             padding: 20px;
#             color: #1a1a2e;
#         }
#
#         .container {
#             max-width: 1200px;
#             margin: 0 auto;
#             background: white;
#             padding: 40px;
#             border-radius: 12px;
#             box-shadow: 0 10px 30px rgba(0,0,0,0.1);
#         }
#          h1 {
#             color: #1a5276;
#             font-size: 2.5em;
#             border-bottom: 4px solid #2ecc71;
#             padding-bottom: 15px;
#             margin-bottom: 30px;
#         }
#
#         h2 {
#             color: #1a5276;
#             font-size: 1.8em;
#             margin-top: 40px;
#             margin-bottom: 20px;
#             border-left: 5px solid #2ecc71;
#             padding-left: 15px;
#         }
#
#         h3 {
#             color: #2c3e50;
#             font-size: 1.3em;
#             margin-top: 25px;
#             margin-bottom: 15px;
#         }
#
#         h4 {
#             color: #34495e;
#             font-size: 1.1em;
#             margin-top: 20px;
#             margin-bottom: 10px;
#         }
#
#         .badge {
#             display: inline-block;
#             background: #2ecc71;
#             color: white;
#             padding: 5px 15px;
#             border-radius: 20px;
#             font-size: 0.8em;
#             font-weight: bold;
#         }
#
#         .section {
#             background: #f8f9fa;
#             padding: 20px 25px;
#             border-radius: 8px;
#             margin: 20px 0;
#             border-left: 4px solid #2ecc71;
#         }
#
#         .section-dark {
#             background: #1a1a2e;
#             color: #ecf0f1;
#             padding: 20px 25px;
#             border-radius: 8px;
#             margin: 20px 0;
#         }
#
#         .section-dark code {
#             color: #2ecc71;
#         }
#
#         table {
#             width: 100%;
#             border-collapse: collapse;
#             margin: 20px 0;
#             font-size: 0.95em;
#         }
#
#         table th {
#             background: #1a5276;
#             color: white;
#             padding: 12px 15px;
#             text-align: left;
#         }
#
#         table td {
#             padding: 10px 15px;
#             border-bottom: 1px solid #ddd;
#         }
#
#         table tr:hover {
#             background: #f1f9ff;
#         }
#
#         code {
#             background: #ecf0f1;
#             padding: 2px 8px;
#             border-radius: 4px;
#             font-family: 'Courier New', monospace;
#             font-size: 0.9em;
#             color: #c0392b;
#         }
#
#         pre {
#             background: #1a1a2e;
#             color: #2ecc71;
#             padding: 20px;
#             border-radius: 8px;
#             overflow-x: auto;
#             margin: 15px 0;
#             font-size: 0.9em;
#         }
#
#         pre code {
#             background: transparent;
#             color: #2ecc71;
#             padding: 0;
#         }
#
#         .highlight-box {
#             background: #eafaf1;
#             border: 2px solid #2ecc71;
#             padding: 20px;
#             border-radius: 8px;
#             margin: 20px 0;
#         }
#
#         .highlight-box-green {
#             background: #f0fff4;
#             border: 3px solid #007A33;
#             padding: 20px;
#             border-radius: 8px;
#             margin: 20px 0;
#             font-family: 'Georgia', serif;
#         }
#
#         ul, ol {
#             margin: 15px 0;
#             padding-left: 30px;
#             line-height: 1.8;
#         }
#
#         li {
#             margin: 5px 0;
#         }
#
#         .grid-2 {
#             display: grid;
#             grid-template-columns: 1fr 1fr;
#             gap: 20px;
#         }
#
#         .grid-3 {
#             display: grid;
#             grid-template-columns: 1fr 1fr 1fr;
#             gap: 20px;
#         }
#
#         .card {
#             background: white;
#             padding: 20px;
#             border-radius: 8px;
#             box-shadow: 0 2px 8px rgba(0,0,0,0.08);
#             border: 1px solid #e8ecf1;
#         }
#
#         .card h4 {
#             color: #1a5276;
#             margin-top: 0;
#         }
#
#         .metric {
#             font-size: 2em;
#             font-weight: bold;
#             color: #1a5276;
#         }
#
#         .metric-label {
#             font-size: 0.9em;
#             color: #7f8c8d;
#         }
#
#         .status-done {
#             background: #2ecc71;
#             color: white;
#             padding: 3px 12px;
#             border-radius: 12px;
#             font-size: 0.8em;
#         }
#
#         .status-warning {
#             background: #f39c12;
#             color: white;
#             padding: 3px 12px;
#             border-radius: 12px;
#             font-size: 0.8em;
#         }
#
#         hr {
#             border: none;
#             border-top: 2px solid #e8ecf1;
#             margin: 30px 0;
#         }
#
#         @media (max-width: 768px) {
#             .container { padding: 20px; }
#             .grid-2, .grid-3 { grid-template-columns: 1fr; }
#             h1 { font-size: 1.8em; }
#             table { font-size: 0.8em; }
#             pre { font-size: 0.8em; padding: 10px; }
#         }
#     </style>
# </head>
# <body>
#     <div class="container">
#
#         <!-- Header -->
#         <h1>🏦 Deep Learning Predictive Modeling of Banking Churn</h1>
#
#         <!-- Project Overview -->
#         <div class="section">
#             <h2>📌 Project Overview</h2>
#             <div class="grid-2">
#                 <div>
#                     <h4>🎯 Aim</h4>
#                     <ul>
#                         <li>Develop an <strong>Artificial Neural Network (ANN)</strong> classification pipeline to predict high-risk churn customers</li>
#                         <li>Leverage <strong>deep learning</strong> to extract patterns from customer behavior data</li>
#                         <li>Provide <strong>actionable insights</strong> for customer retention strategies</li>
#                         <li>Minimize revenue loss through <strong>proactive, data-driven predictions</strong></li>
#                     </ul>
#                 </div>
#                 <div>
#                     <h4>📊 Dataset Summary</h4>
#                     <ul>
#                         <li><strong>Records:</strong> 10,000 customers</li>
#                         <li><strong>Features:</strong> 13 (demographic, financial, account)</li>
#                         <li><strong>Target:</strong> Exited (1 = Churned, 0 = Retained)</li>
#                         <li><strong>Churn Rate:</strong> 20.37%</li>
#                     </ul>
#                 </div>
#             </div>
#         </div>
#
#         <!-- Dataset Features -->
#         <h2>📊 Dataset Features</h2>
#         <table>
#             <thead>
#                 <tr>
#                     <th>Feature</th>
#                     <th>Description</th>
#                 </tr>
#             </thead>
#             <tbody>
#                 <tr><td><strong>RowNumber</strong></td><td>Unique row index (1–10,000)</td></tr>
#                 <tr><td><strong>CustomerId</strong></td><td>Unique identifier assigned to each customer</td></tr>
#                 <tr><td><strong>Surname</strong></td><td>Customer's last name</td></tr>
#                 <tr><td><strong>CreditScore</strong></td><td>Numerical credit score representing customer creditworthiness</td></tr>
#                 <tr><td><strong>Geography</strong></td><td>Customer's country or region (France, Germany, Spain)</td></tr>
#                 <tr><td><strong>Gender</strong></td><td>Customer gender (Male/Female)</td></tr>
#                 <tr><td><strong>Age</strong></td><td>Customer age in years</td></tr>
#                 <tr><td><strong>Tenure</strong></td><td>Number of years the customer has been with the bank</td></tr>
#                 <tr><td><strong>Balance</strong></td><td>Customer account balance</td></tr>
#                 <tr><td><strong>NumOfProducts</strong></td><td>Total number of banking products used by the customer</td></tr>
#                 <tr><td><strong>HasCrCard</strong></td><td>Indicates whether the customer owns a credit card (1 = Yes, 0 = No)</td></tr>
#                 <tr><td><strong>IsActiveMember</strong></td><td>Indicates whether the customer is an active bank member (1 = Active, 0 = Inactive)</td></tr>
#                 <tr><td><strong>Exited</strong></td><td><span class="badge">Target Variable</span> (1 = Customer left, 0 = Customer retained)</td></tr>
#             </tbody>
#         </table>
#
#         <!-- Data Verification -->
#         <h2>🔍 Data Verification</h2>
#         <div class="grid-3">
#             <div class="card">
#                 <div class="metric">10,000</div>
#                 <div class="metric-label">Total Records</div>
#             </div>
#             <div class="card">
#                 <div class="metric">13</div>
#                 <div class="metric-label">Total Features</div>
#             </div>
#             <div class="card">
#                 <div class="metric">0</div>
#                 <div class="metric-label">Missing Values</div>
#             </div>
#         </div>
#
#         <pre>
# <code># Data Verification Code
# print(f"Dataset Shape: {df.shape}")
# print(f"Missing Values: {df.isnull().sum().sum()}")
# print(f"Duplicate Values: {df.duplicated().sum()}")
# print(f"Target Distribution:\n{df['Exited'].value_counts()}")</code>
#         </pre>
#
#         <div class="highlight-box">
#             <strong>📌 Output:</strong><br>
#             <code>Dataset Shape: (10000, 13)</code><br>
#             <code>Missing Values: 0</code><br>
#             <code>Duplicate Values: 0</code><br>
#             <code>Target Distribution: 0 = 7963 (79.63%), 1 = 2037 (20.37%)</code>
#         </div>
#
#         <!-- EDA -->
#         <h2>🔎 Exploratory Data Analysis (EDA)</h2>
#
#         <div class="grid-2">
#             <div class="section">
#                 <h4>👤 Customer Activity Status</h4>
#                 <ul>
#                     <li><strong>Active Members:</strong> 5,151 customers</li>
#                     <li><strong>Inactive Members:</strong> 4,849 customers</li>
#                     <li>✅ Retention is high across both groups</li>
#                     <li>🎯 Inactive members show slightly higher churn rates</li>
#                 </ul>
#                 <pre>
# <code># Code
# ax = sns.countplot(x=df['IsActiveMember'], hue=df['Exited'])
# for p in ax.containers:
#     ax.bar_label(p)</code>
#                 </pre>
#             </div>
#
#             <div class="section">
#                 <h4>🌍 Average Balance by Geography</h4>
#                 <ul>
#                     <li><strong>Germany:</strong> Highest average balance</li>
#                     <li><strong>France:</strong> Moderate average balance</li>
#                     <li><strong>Spain:</strong> Moderate average balance</li>
#                 </ul>
#                 <pre>
# <code># Code
# df.groupby(["Geography"])["Balance"].mean().plot(kind="barh")</code>
#                 </pre>
#             </div>
#         </div>
#
#         <div class="grid-2">
#             <div class="section">
#                 <h4>👫 Gender & Tenure Analysis</h4>
#                 <ul>
#                     <li>👩 Female customers slightly outnumber males</li>
#                     <li>📈 Retention is high for both genders</li>
#                     <li>🎯 Gender combined with other features improves prediction</li>
#                 </ul>
#             </div>
#
#             <div class="section">
#                 <h4>📊 Key Correlations with Churn</h4>
#                 <table>
#                     <tr><td><strong>Age ↔ Exited</strong></td><td>+0.29</td><td>Moderate positive</td></tr>
#                     <tr><td><strong>Balance ↔ Exited</strong></td><td>+0.12</td><td>Weak positive</td></tr>
#                     <tr><td><strong>NumOfProducts ↔ Exited</strong></td><td>-0.12</td><td>Weak negative</td></tr>
#                     <tr><td><strong>IsActiveMember ↔ Exited</strong></td><td>-0.16</td><td>Moderate negative</td></tr>
#                 </table>
#             </div>
#         </div>
#
#         <!-- Data Preprocessing -->
#         <h2>🛠️ Data Preprocessing</h2>
#
#         <div class="highlight-box-green">
#             <h4>🔄 Categorical Feature Encoding</h4>
#             <ul>
#                 <li><strong>One-Hot Encoding</strong> applied to categorical variables using <code>get_dummies()</code></li>
#                 <li>Encoded features: Geography_France, Geography_Germany, Geography_Spain, Gender_Female, Gender_Male</li>
#                 <li><strong>Final Features:</strong> 12 input features, 1 target variable (Exited)</li>
#             </ul>
#             <pre>
# <code># Encoding
# cat_columns = df.select_dtypes(include=['object']).columns
# df = pd.get_dummies(df, columns=cat_columns)
#
# # Split
# X = df.drop("Exited", axis=1)
# y = df["Exited"]
#
# # Scaling
# scaler = MinMaxScaler()
# X_scaled = scaler.fit_transform(X)</code>
#             </pre>
#         </div>
#
#         <div class="grid-3">
#             <div class="card">
#                 <h4>📦 Train Set</h4>
#                 <div class="metric">7,200</div>
#                 <div class="metric-label">Samples (72%)</div>
#             </div>
#             <div class="card">
#                 <h4>🔬 Validation Set</h4>
#                 <div class="metric">800</div>
#                 <div class="metric-label">Samples (8%)</div>
#             </div>
#             <div class="card">
#                 <h4>🧪 Test Set</h4>
#                 <div class="metric">2,000</div>
#                 <div class="metric-label">Samples (20%)</div>
#             </div>
#         </div>
#
#         <!-- Model Architecture -->
#         <h2>🧠 Model Architecture</h2>
#
#         <div class="section">
#             <h4>Base ANN Architecture</h4>
#             <pre>
# <code>model = Sequential([
#     Dense(15, activation="relu", input_dim=X_train.shape[1]),
#     Dense(10, activation="relu"),
#     Dense(6, activation="relu"),
#     Dense(4, activation="relu"),
#     Dense(1, activation="sigmoid")
# ])
#
# model.compile(optimizer="adam", loss="binary_crossentropy", metrics=["Recall"])</code>
#             </pre>
#         </div>
#
#         <!-- Model Variations -->
#         <h3>🔬 Model Variations Tested</h3>
#         <table>
#             <thead>
#                 <tr>
#                     <th>Model</th>
#                     <th>Configuration</th>
#                     <th>Precision</th>
#                     <th>Recall</th>
#                     <th>AP Score</th>
#                 </tr>
#             </thead>
#             <tbody>
#                 <tr><td><strong>1</strong></td><td>Non Class-weight</td><td>0.699</td><td>0.536</td><td>0.469</td></tr>
#                 <tr><td><strong>2</strong></td><td>Class-weight</td><td>0.445</td><td>0.789</td><td>0.394</td></tr>
#                 <tr><td><strong>3</strong></td><td>Class-weight + Learning Rate</td><td>0.479</td><td>0.757</td><td>0.412</td></tr>
#                 <tr><td><strong>4</strong></td><td>Class-weight + LR + Dropout</td><td>0.454</td><td>0.764</td><td>0.395</td></tr>
#                 <tr style="background:#eafaf1;"><td><strong>5</strong> ⭐</td><td>Class-weight + LR + EarlyStop (val_loss)</td><td><strong>0.578</strong></td><td><strong>0.658</strong></td><td><strong>0.450</strong></td></tr>
#                 <tr><td><strong>6</strong></td><td>Class-weight + LR + EarlyStop (val_recall)</td><td>0.244</td><td>0.840</td><td>0.238</td></tr>
#                 <tr><td><strong>7</strong></td><td>Optuna Optimized</td><td>0.385</td><td>0.830</td><td>0.354</td></tr>
#             </tbody>
#         </table>
#
#         <!-- Best Model Results -->
#         <h2>🏆 Best Model Results (Model 5)</h2>
#
#         <div class="section-dark">
#             <pre>
# <code>63/63 [==============================] - 0s 1ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.89      0.94      0.91      1593
#            1       0.70      0.54      0.61       407
#
#     accuracy                           0.86      2000
#    macro avg       0.79      0.74      0.76      2000
# weighted avg       0.85      0.86      0.85      2000
#
# Confusion Matrix:
# [[1499   94]
#  [ 189  218]]
#
# AUC Score: 0.861</code>
#             </pre>
#         </div>
#
#         <div class="grid-3">
#             <div class="card">
#                 <div class="metric">86%</div>
#                 <div class="metric-label">Accuracy</div>
#             </div>
#             <div class="card">
#                 <div class="metric">0.861</div>
#                 <div class="metric-label">AUC Score</div>
#             </div>
#             <div class="card">
#                 <div class="metric">70%</div>
#                 <div class="metric-label">Precision (Churn)</div>
#             </div>
#         </div>
#
#         <!-- Key Insights -->
#         <h2>💡 Key Insights & Findings</h2>
#
#         <div class="grid-2">
#             <div>
#                 <h4>📈 Important Features</h4>
#                 <table>
#                     <tr><td><strong>Age</strong></td><td>+0.29</td><td>Strong positive</td></tr>
#                     <tr><td><strong>IsActiveMember</strong></td><td>-0.16</td><td>Moderate negative</td></tr>
#                     <tr><td><strong>NumOfProducts</strong></td><td>-0.12</td><td>Weak negative</td></tr>
#                     <tr><td><strong>Balance</strong></td><td>+0.12</td><td>Weak positive</td></tr>
#                 </table>
#             </div>
#             <div>
#                 <h4>👥 Demographic Insights</h4>
#                 <ul>
#                     <li>🇩🇪 Germany has highest average account balances</li>
#                     <li>👩 Female customers show slightly higher retention</li>
#                     <li>🌍 Geographical differences affect customer behavior</li>
#                     <li>📅 Older customers more likely to churn</li>
#                 </ul>
#             </div>
#         </div>
#
#         <!-- Business Recommendations -->
#         <h2>🎯 Business Recommendations</h2>
#
#         <div class="grid-2">
#             <div class="section">
#                 <h4>👤 Customer Retention Strategy</h4>
#                 <ul>
#                     <li><strong>Focus on inactive members</strong> - Higher churn rates</li>
#                     <li><strong>Target older customers</strong> - Higher correlation with churn</li>
#                     <li><strong>Promote additional products</strong> - More products = more loyalty</li>
#                 </ul>
#             </div>
#             <div class="section">
#                 <h4>🎯 Targeted Interventions</h4>
#                 <table>
#                     <tr><td><strong>Inactive Members</strong></td><td>Re-engagement campaigns</td></tr>
#                     <tr><td><strong>High Age Customers</strong></td><td>Personalized services</td></tr>
#                     <tr><td><strong>German Customers</strong></td><td>Region-specific programs</td></tr>
#                     <tr><td><strong>High Balance</strong></td><td>Wealth management services</td></tr>
#                 </table>
#             </div>
#         </div>
#
#         <div class="highlight-box">
#             <h4>📋 Operational Improvements</h4>
#             <ul>
#                 <li><strong>Early warning system</strong> using the ANN model</li>
#                 <li><strong>Proactive outreach</strong> to high-risk customers</li>
#                 <li><strong>Personalized offers</strong> based on churn probability</li>
#                 <li><strong>Monitor key metrics</strong> (activity status, product usage)</li>
#             </ul>
#         </div>
#
#         <!-- Future Improvements -->
#         <h2>🔮 Future Improvements</h2>
#         <table>
#             <thead>
#                 <tr>
#                     <th>Area</th>
#                     <th>Enhancement</th>
#                 </tr>
#             </thead>
#             <tbody>
#                 <tr><td><strong>Data Collection</strong></td><td>Behavioral data, transaction history, support interactions</td></tr>
#                 <tr><td><strong>Feature Engineering</strong></td><td>Customer lifetime value, spending patterns, seasonal effects</td></tr>
#                 <tr><td><strong>Advanced Models</strong></td><td>LSTM for sequential data, ensemble methods</td></tr>
#                 <tr><td><strong>Real-time Scoring</strong></td><td>Deploy model as API for real-time predictions</td></tr>
#                 <tr><td><strong>A/B Testing</strong></td><td>Validate model's business impact with controlled experiments</td></tr>
#             </tbody>
#         </table>
#
#         <!-- Technical Stack -->
#         <h2>🛠️ Technical Stack</h2>
#         <pre>
# <code>pip install pandas numpy matplotlib seaborn scikit-learn
# pip install tensorflow keras
# pip install optuna
# pip install imbalanced-learn</code>
#         </pre>
#
#         <!-- Project Structure -->
#         <h2>📁 Project Structure</h2>
#         <pre>
# <code>Banking-Churn-Prediction/
# │
# ├── data/
# │   └── churn_data.csv
# │
# ├── notebooks/
# │   ├── 01_EDA.ipynb
# │   ├── 02_Preprocessing.ipynb
# │   └── 03_Model_Training.ipynb
# │
# ├── src/
# │   ├── data_preprocessing.py
# │   ├── model_architecture.py
# │   ├── model_training.py
# │   └── model_evaluation.py
# │
# ├── models/
# │   ├── best_model.h5
# │   └── scaler.pkl
# │
# ├── README.md
# └── requirements.txt</code>
#         </pre>
#
#         <!-- Summary -->
#         <h2>📝 Summary</h2>
#
#         <div class="highlight-box-green">
#             <h3>✅ What We Achieved</h3>
#             <ul>
#                 <li>Developed <strong>7 ANN models</strong> with different optimization strategies</li>
#                 <li>Achieved <strong>86% accuracy</strong> with <strong>0.861 AUC Score</strong></li>
#                 <li>Identified <strong>key churn predictors</strong> (Age, IsActiveMember, NumOfProducts)</li>
#                 <li>Created <strong>actionable business insights</strong> for customer retention</li>
#             </ul>
#
#             <h3>💡 Key Takeaways</h3>
#             <ul>
#                 <li><strong>Class imbalance</strong> requires careful handling (class weighting, appropriate metrics)</li>
#                 <li><strong>Validation-based early stopping</strong> (val_loss) provides best performance</li>
#                 <li><strong>ANN models</strong> effectively capture complex patterns in customer data</li>
#                 <li><strong>Business value</strong> lies in interpretable insights, not just model metrics</li>
#             </ul>
#         </div>
#
#         <hr>
#
#         <div style="text-align: center; padding: 20px 0; color: #7f8c8d;">
#             <p><strong>Status:</strong> <span class="status-done">✅ Complete</span></p>
#             <p><strong>Best Model:</strong> ANN with Class-weight + LR + Early Stopping (val_loss)</p>
#             <p><strong>Business Impact:</strong> Early detection of at-risk customers enabling proactive retention</p>
#             <p style="margin-top: 15px; font-size: 0.9em;">
#                 Built with ❤️ using Python, TensorFlow, and Scikit-learn
#             </p>
#         </div>
#
#     </div>
# </body>
# </html>
